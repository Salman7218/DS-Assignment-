# %%
"""Q1. hat is multithreading in python? hy is it used? Name the module used to handle threads in python.
Ans.:Multithreading in Python refers to the process of running multiple threads of execution concurrently within a single program. Each thread 
represents a separate flow of control that can perform tasks in parallel with other threads.

Multithreading is used in Python to achieve parallelism and improve the performance of certain types of tasks, such as I/O-bound operations 
(e.g., reading and writing files, network communication) or CPU-bound operations that can be parallelized (e.g., image processing, data analysis).

The threading module in Python is used to handle threads. It provides a simple and efficient way to create, manage, and communicate between 
threads. With the threading module, you can create and start new threads, set thread-specific data, synchronize access to shared resources, 
and communicate between threads using various synchronization primitives such as locks, semaphores, and events.

To use the threading module, you can import it as follows:

import threading

Then, you can create a new thread by defining a function that represents the thread's behavior and passing it to the Thread constructor:

def my_thread_function():
    # thread behavior goes here

my_thread = threading.Thread(target=my_thread_function)
my_thread.start()

The start() method starts the thread's execution, which runs the my_thread_function in a separate flow of control. You can also use various methods of 
the Thread class to manage the thread's state, such as join(), is_alive(), and setDaemon()."""

# %%
"""1. why threading module used? write the use of the following functions
activeCount()
currentThread()
enumerate()
Ans.: The threading module in Python is used to create and manage threads in a program. Threads are a lightweight way to achieve concurrency and 
improve the performance of certain types of tasks, such as I/O-bound operations and CPU-bound operations that can be parallelized.

Here are the uses of the following functions of the threading module:

1. activeCount(): This function returns the number of threads that are currently active and running in the program. It can be used to monitor the 
progress of a program that uses multiple threads.

2. currentThread(): This function returns a reference to the current thread object that is calling it. It can be used to access information about 
the current thread, such as its name, ID, and state.

3. numerate(): This function returns a list of all thread objects that are currently active and running in the program. It can be used to iterate 
over all threads and perform operations on each thread, such as joining or terminating it.

Here's an example of how to use these functions:"""

import threading

def my_thread_function():
    
    pass

my_thread_1 = threading.Thread(target=my_thread_function)
my_thread_2 = threading.Thread(target=my_thread_function)

my_thread_1.start()
my_thread_2.start()

num_threads = threading.activeCount()
print("Number of active threads:", num_threads)

current_thread = threading.currentThread()
print("Current thread name:", current_thread.name)

all_threads = threading.enumerate()
print("All threads:", all_threads)
# Out:
# Number of active threads: 8
# Current thread name: MainThread
# All threads: [<_MainThread(MainThread, started 139743463286592)>, <Thread(IOPub, started daemon 139743392757312)>, <Heartbeat(Heartbeat, started daemon 139743384364608)>, <Thread(Thread-3 (_watch_pipe_fd), started daemon 139743359186496)>, <Thread(Thread-4 (_watch_pipe_fd), started daemon 139743350793792)>, <ControlThread(Control, started daemon 139743002097216)>, <HistorySavingThread(IPythonHistorySavingThread, started 139742993704512)>, <ParentPollerUnix(Thread-2, started daemon 139742985311808)>]
# /tmp/ipykernel_465/3319064161.py:36: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   num_threads = threading.activeCount()
# /tmp/ipykernel_465/3319064161.py:40: DeprecationWarning: currentThread() is deprecated, use current_thread() instead
#   current_thread = threading.currentThread()

# %%
"""3. Explain the following functions:
 1. run()
 2. start()
 3. join()
 4. isAlive()
 Ans.: In the threading module of Python, the Thread class provides several methods that are used to manage threads. Here's a brief explanation 
 of the following methods:

1. run(): This method is called when the start() method of a Thread object is called. It represents the entry point of the thread's behavior and 
contains the code that will be executed in the thread's context. You can override this method to customize the behavior of a thread.

2. start(): This method starts the execution of a thread by calling its run() method in a separate flow of control. It does not block the main thread,
so other threads can run concurrently with it. If a thread is already running, calling start() again will have no effect.

3. join(): This method waits for a thread to complete its execution and blocks the calling thread until the target thread has finished. It is typically 
used to synchronize the completion of multiple threads or to ensure that a thread has finished its task before continuing with the main thread.

4. isAlive(): This method returns a boolean value indicating whether a thread is currently running or not. It can be used to check the status of a 
thread and take appropriate actions based on its state. For example, you can use isAlive() to determine whether a thread has finished its task before 
joining it."""

# %%
"""4. write a python program to create two threads. Thread one must print the list of squares and thread
two must print the list of cubes.
Ans.:"""

import threading

def print_squares(n):
    for i in range(n):
        print(i*i)

def print_cubes(n):
    for i in range(n):
        print(i*i*i)

# create two threads
t1 = threading.Thread(target=print_squares, args=(10,))
t2 = threading.Thread(target=print_cubes, args=(10,))

# start the threads
t1.start()
t2.start()

# wait for the threads to finish
t1.join()
t2.join()
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729

# %%
"""Q5. State advantages and disadvantages of multithreading
Ans.:Multithreading is a powerful tool that allows programs to execute multiple threads of execution concurrently within the same process. However, 
like any tool, it has both advantages and disadvantages, which are discussed below.

Advantages of multithreading:

1. Increased performance: Multithreading allows programs to take advantage of the available CPU resources and execute multiple threads of execution 
concurrently. This can result in significant performance gains, especially in programs that perform computationally-intensive tasks.

2. Improved responsiveness: Multithreading allows programs to perform tasks in the background while still allowing the user to interact with the 
program's user interface. This can improve the overall responsiveness of the program and enhance the user experience.

3. Simplified design: Multithreading can simplify the design of programs by breaking them down into smaller, more manageable units of work that can 
be executed concurrently. This can make the code easier to understand, test, and maintain.

Disadvantages of multithreading:

1. Increased complexity: Multithreading introduces additional complexity into programs, making them harder to understand, test, and debug. This is 
especially true in programs that involve shared resources, such as memory, files, or network connections, which can be difficult to manage in a
multithreaded environment.

2. Synchronization issues: Multithreading requires careful synchronization of shared resources to prevent race conditions, deadlocks, and other 
synchronization issues. This can be difficult to achieve, especially in complex programs.

3. Increased resource usage: Multithreading can consume additional system resources, such as CPU cycles, memory, and I/O bandwidth. This can impact 
the performance of other programs running on the same system.

# %%
"""6. Explain deadlocks and race conditions.
Ans.: Deadlocks and race conditions are two common synchronization issues that can occur in multithreaded programs.

Deadlocks occur when two or more threads are blocked waiting for each other to release a shared resource, such as a lock or a semaphore. Deadlocks 
can occur when multiple threads acquire locks in a different order, leading to a situation where each thread is waiting for a lock that is held by 
another thread, resulting in a deadlock.

For example, consider two threads T1 and T2 that need to acquire two locks L1 and L2, but they acquire them in a different order. T1 acquires L1 
and then tries to acquire L2, while T2 acquires L2 and then tries to acquire L1. If both threads execute concurrently, they may acquire their 
respective locks before being blocked while waiting for the other lock to be released, resulting in a deadlock.

Race conditions occur when two or more threads access a shared resource concurrently without proper synchronization, leading to unexpected results. 
Race conditions can occur when threads modify shared data without proper synchronization or when multiple threads perform operations on the same 
shared data without coordinating their actions."""
